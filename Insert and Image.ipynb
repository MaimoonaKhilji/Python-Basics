# %% [markdown]
# Download the image and note down the path. Then
#
#     step-0: Markdown the line
#     step-1: Go to Edit
#     Step-2: Select Insert Image
#     Step-3: Upload Image
#     Step-4: Run the command

# %% [markdown]
# ![penguin.png](attachment:penguin.png)

# %% [markdown]
# ## Thank You!
